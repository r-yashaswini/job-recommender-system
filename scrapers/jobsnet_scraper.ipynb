# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import pandas as pd
import time
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                  '(KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 '
                  'Edg/87.0.664.75'
}
BLOCKED_KEYWORDS = {'telegram', 'jobsnet', 'acciojob', 'whatsapp'}

DAYS_BACK = 30
BASE_URL = "https://jobsnet.in/page/{}/"

jobs = []

today = datetime.today().date()
cutoff_date = today - timedelta(days=DAYS_BACK)

print(f"Starting JobsNet scraper... (Last {DAYS_BACK} days)")

page_num = 1
stop_pagination = False

while not stop_pagination:
    page_url = BASE_URL.format(page_num)
    print(f"Fetching: {page_url}")

    soup = None
    for attempt in range(3):
        try:
            response = requests.get(page_url, headers=HEADERS, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            break
        except Exception as e:
            if attempt == 2:
                print(f"Failed to fetch {page_url}: {e}")
            time.sleep(2 ** attempt)

    if not soup:
        break

    articles = soup.find_all("article")
    if not articles:
        print("No articles found")
        break

    for article in articles:
        job = {}

        title_tag = article.find("h3", class_="entry-title")
        if title_tag:
            a_tag = title_tag.find("a", href=True)
            if a_tag:
                job["title"] = a_tag.text.strip()
                job["listing_url"] = a_tag["href"]

        time_tag = article.find("time")
        if time_tag:
            try:
                job_date = datetime.strptime(
                    time_tag.text.strip(), "%B %d, %Y"
                ).date()
                job["posted_date"] = job_date
            except ValueError:
                continue

        if not job.get("listing_url"):
            continue

        if job.get("posted_date") and job["posted_date"] < cutoff_date:
            stop_pagination = True
            print(f"Reached cutoff date: {job['posted_date']}")
            break

        jobs.append(job)

    page_num += 1

print(f"Found {len(jobs)} job listings. Enriching details...")

enriched_jobs = []

for i, job in enumerate(jobs, 1):
    print(f"Processing job {i}/{len(jobs)}: {job.get('title', '')[:50]}...")

    soup = None
    for attempt in range(3):
        try:
            response = requests.get(job["listing_url"], headers=HEADERS, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            break
        except Exception:
            time.sleep(2 ** attempt)

    if not soup:
        continue

    job_info = job.copy()

    apply_urls = set()
    for a in soup.find_all("a", href=True):
        anchor_text = a.get_text(strip=True).lower()
        if any(x in anchor_text for x in ("apply here", "click here", "apply now")):
            url = a["href"]
            if not any(b in url.lower() for b in BLOCKED_KEYWORDS):
                apply_urls.add(url)

    job_info["apply_urls"] = list(apply_urls)

    for p in soup.find_all("p"):
        text_lower = p.get_text(strip=True).lower()
        if "location" in text_lower and ":" in p.text:
            job_info["location"] = p.text.split(":", 1)[-1].strip()
        elif "experience" in text_lower and ":" in p.text:
            job_info["experience"] = p.text.split(":", 1)[-1].strip()

    descriptions = []

    for ul in soup.find_all("ul", class_="wp-block-list"):
        for li in ul.find_all("li"):
            txt = li.get_text(strip=True)
            if txt:
                descriptions.append(txt)

    for p in soup.find_all("p"):
        txt = p.get_text(strip=True)
        if txt.startswith(("•", "-", "–", "*")):
            descriptions.append(txt.lstrip("•-–* ").strip())

    if descriptions:
        job_info["description"] = " ".join(dict.fromkeys(descriptions))
    else:
        job_info["description"] = (
            "No detailed description available. Please visit the apply link for more information."
        )

    enriched_jobs.append(job_info)

normalized_jobs = []

for job in enriched_jobs:
    urls = job.get("apply_urls", [])
    if urls:
        for url in urls:
            new_job = job.copy()
            new_job["apply_url"] = url
            new_job.pop("apply_urls", None)
            normalized_jobs.append(new_job)
    else:
        new_job = job.copy()
        new_job["apply_url"] = None
        new_job.pop("apply_urls", None)
        normalized_jobs.append(new_job)

df = pd.DataFrame(normalized_jobs)

df["location"] = df.get("location", "Across India")
df["experience"] = df.get("experience", "Freshers")
df["description"] = df.get(
    "description",
    "No detailed description available. Please visit the apply link for more information."
)
df["apply_url"] = df["apply_url"].fillna(df["listing_url"])
df["source"] = "jobsnet"

print(f"Scraping completed. Total jobs: {len(df)}")

print("\nFirst 5 jobs:")
print(df[["title", "posted_date", "location", "experience"]].head())
# Out:
# Starting JobsNet scraper... (Last 30 days)
# Fetching: https://jobsnet.in/page/1/
# Fetching: https://jobsnet.in/page/2/
# Fetching: https://jobsnet.in/page/3/
# Reached cutoff date: 2025-12-28
# Found 86 job listings. Enriching details...
# Processing job 1/86: Cepheid Software Engineer Hiring Challenge 2026 | ...
# Processing job 2/86: Microsoft Off Campus Drive 2026: Hiring Entry Leve...
# Processing job 3/86: Cognizant Off Campus Drive Hiring Analyst Trainee ...
# Processing job 4/86: Hitachi Energy Off Campus Drive 2026 – Hiring Entr...
# Processing job 5/86: Qualcomm Off Campus Drive 2026 | Associate Softwar...
# Processing job 6/86: Unisys Off Campus Drive 2026 | Associate Cybersecu...
# Processing job 7/86: Equifax Off Campus Drive 2026 – Hiring Technology ...
# Processing job 8/86: Oracle Hiring Entry-level Associate Test Engineers...
# Processing job 9/86: HSBC Off Campus Drive 2026 | Trainee Apprentice – ...
# Processing job 10/86: Capgemini Off Campus Drive 2026 | Network Engineer...
# Processing job 11/86: HPE Off Campus Drive 2026 – Hiring Graduate Softwa...
# Processing job 12/86: Infosys Off Campus Drive 2026 For Specialist Progr...
# Processing job 13/86: Target Corporation Off Campus Hiring Technology Ap...
# Processing job 14/86: Oracle Hiring Entry-level Software Developer (0-2 ...
# Processing job 15/86: Micron Technology Off Campus Drive 2026 – Associat...
# Processing job 16/86: Guidehouse Off Campus Drive 2026 – Hiring Associat...
# Processing job 17/86: FIS Global Hiring Entry-Level Java Support with C,...
# Processing job 18/86: Nielsen Recruitment Drive 2026 – Hiring Member Of ...
# Processing job 19/86: Swiggy Hiring Associate Software Engineer – Androi...
# Processing job 20/86: Yash Technologies Off Campus Drive 2026: Trainee –...
# Processing job 21/86: Red Hat Off Campus Drive 2026 : Associate Software...
# Processing job 22/86: IBM Off Campus Drive 2026 – Hiring Freshers As Ass...
# Processing job 61/86: Cisco Off Campus Drive 2026 | Technical Graduate A...
# Processing job 62/86: Zebra Technologies Off Campus Drive 2026 | Softwar...
# Processing job 63/86: Konecranes Off Campus Drive 2026 Hiring Graduate E...
# Processing job 64/86: S&P Global Off Campus Drive 2026 | Associate Softw...
# Processing job 65/86: IBM Hiring Freshers As Associate System Engineer –...
# Processing job 66/86: Dassault Systèmes Off Campus Drive 2026 – Apprenti...
# Processing job 67/86: Equifax Off Campus Drive 2026 – Hiring Entry-Level...
# Processing job 68/86: Cummins Off Campus Drive 2026 | Data Analytics Eng...
# Processing job 69/86: Rockwell Automation Hiring Entry-Level Associate s...
# Processing job 70/86: Honeywell  Hiring Entry-Level Software Engineers –...
# Processing job 71/86: EY GDS Off Campus Drive 2026 Hiring Freshers As As...
# Processing job 72/86: Qualcomm Off Campus Drive 2026 – Hiring Software E...
# Processing job 73/86: SAP Labs Hiring Entry-Level Associate Consultant- ...
# Processing job 74/86: Accenture Hiring Application Support Engineer – An...
# Processing job 75/86: Cognizant is Hiring Entry-Level PL/SQL Software En...
# Processing job 76/86: SITA Off Campus Drive 2026 Hiring Graduate – Devel...
# Processing job 77/86: IQVIA Off Campus Drive 2026 Hiring  Software Devel...
# Processing job 78/86: FIS Global Hiring 2026: Hiring Software Test Analy...
# Processing job 79/86: Natwest Technology Off Campus  Drive 2026 : Hiring...
# Processing job 80/86: Bajaj Finance Off Campus Drive 2026 Hiring Junior ...
# Processing job 81/86: NNE Off Campus Drive 2026 – Hiring Trainee Enginee...
# Processing job 82/86: Citi Group Off Campus Drive 2026 – Hiring GenAI De...
# Processing job 83/86: CGI Off Campus Drive 2026 | AI/ML Apprentice | Fre...
# Processing job 84/86: Konecranes Off Campus Drive 2026 – Hiring Software...
# Processing job 85/86: TCS Ignite & Smart Off Campus Drive 2026 Hiring Fr...
# Processing job 86/86: Teradata Off Campus Drive 2026 Hiring Entry-Level ...
# Scraping completed. Total jobs: 92
#
# First 5 jobs:
#                                                title posted_date  \
# 0  Cepheid Software Engineer Hiring Challenge 202...  2026-01-27
# 1  Microsoft Off Campus Drive 2026: Hiring Entry ...  2026-01-27
# 2  Cognizant Off Campus Drive Hiring Analyst Trai...  2026-01-27
# 3  Hitachi Energy Off Campus Drive 2026 – Hiring ...  2026-01-27
# 4  Qualcomm Off Campus Drive 2026 | Associate Sof...  2026-01-27
#
#                                location          experience
# 0                                   NaN                 NaN
# 1                             Pan India  Freshers/0-2 Years
# 2                                                  Freshers
# 3                               Chennai   Freshers/0-4 Year
# 4  Hyderabad, Bangalore, Chennai, Noida         0-1 Years….

# %%
from sqlalchemy import create_engine
import pandas as pd
DB_URL = "postgresql+psycopg2://postgres:Sunny$123@localhost:35432/pgvector"
engine = create_engine(DB_URL)
df.to_sql(
    name="jobs",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=500
)
