# %%
from bs4 import BeautifulSoup
import requests
from datetime import *
import pandas as pd
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 Edg/87.0.664.75'}

# %%
jobs = []
today = datetime.today().date()
cutoff_date = today - timedelta(days=30)
page_num = 1
stop_pagination = False
while not stop_pagination:
    page_url = f"https://jobsnet.in/page/{page_num}/"
    print(f"Fetching: {page_url}") # Checking
    response = requests.get(page_url, headers=head, timeout=10)
    soup = BeautifulSoup(response.content, "html.parser")
    articles = soup.find_all("article")
    if not articles:
        break  
    for article in articles:
        job = {}
        title_tag = article.find("h3", class_="entry-title")
        if title_tag:
            a_tag = title_tag.find("a", href=True)
            if a_tag:
                job["title"] = a_tag.text.strip()
                job["listing_url"] = a_tag["href"]
        time_tag = article.find("time")
        if time_tag:
            job_date = datetime.strptime(time_tag.text.strip(), "%B %d, %Y").date()
            job["posted_date"] = job_date
            if job_date < cutoff_date:
                stop_pagination = True
                break
        if job.get("listing_url"):
            jobs.append(job)
    if stop_pagination:
        break
    page_num += 1
for job in jobs:
    print(job)
# Out:
# Fetching: https://jobsnet.in/page/1/
# Fetching: https://jobsnet.in/page/2/
# Fetching: https://jobsnet.in/page/3/
# {'title': 'Unisys Off Campus Drive 2026 | Associate Cybersecurity  Engineer | 0-2 Years', 'listing_url': 'https://jobsnet.in/unisys-off-campus-drive-associate-cybersecurity-engineer/', 'posted_date': datetime.date(2026, 1, 26)}
# {'title': 'Equifax Off Campus Drive 2026 – Hiring Technology Engineering Trainee', 'listing_url': 'https://jobsnet.in/equifax-off-campus-drive-hiring-technology-engineering-trainee/', 'posted_date': datetime.date(2026, 1, 26)}
# {'title': 'Oracle Hiring Entry-level Associate Test Engineers 0-2 Years Experience', 'listing_url': 'https://jobsnet.in/oracle-hiring-entry-level-associate-test-engineers/', 'posted_date': datetime.date(2026, 1, 26)}
# {'title': 'HSBC Off Campus Drive 2026 | Trainee Apprentice – IT Auditor', 'listing_url': 'https://jobsnet.in/hsbc-off-campus-drive-trainee-apprentice-it-auditor/', 'posted_date': datetime.date(2026, 1, 26)}
# {'title': 'Capgemini Off Campus Drive 2026 | Network Engineer | BE/B.Tech/MCA | PAN India', 'listing_url': 'https://jobsnet.in/capgemini-off-campus-drive-network-engineer/', 'posted_date': datetime.date(2026, 1, 25)}
# {'title': 'HPE Off Campus Drive 2026 – Hiring Graduate Software Engineer (0-2 Yrs)', 'listing_url': 'https://jobsnet.in/hpe-off-campus-drive-hiring-graduate-software-engineer/', 'posted_date': datetime.date(2026, 1, 24)}
# {'title': 'Infosys Off Campus Drive 2026 For Specialist Programmer / Digital Specialist Engineer', 'listing_url': 'https://jobsnet.in/infosys-off-campus-drive-for-specialist-programmer-and-dse/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Target Corporation Off Campus Hiring Technology Apprentice – Freshers', 'listing_url': 'https://jobsnet.in/target-corporation-off-campus-hiring-technology-freshers/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Oracle Hiring Entry-level Software Developer (0-2 Years)', 'listing_url': 'https://jobsnet.in/oracle-off-campus-drive/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Micron Technology Off Campus Drive 2026 – Associate Engineer – Full Stack', 'listing_url': 'https://jobsnet.in/micron-technology-off-campus-drive-associate-engineer-full-stack/', 'posted_date': datetime.date(2026, 1, 22)}
# {'title': 'Guidehouse Off Campus Drive 2026 – Hiring Associate Software Engineer Freshers', 'listing_url': 'https://jobsnet.in/guidehouse-off-campus-drive-hiring-associate-software-engineer-freshers/', 'posted_date': datetime.date(2026, 1, 22)}
# {'title': 'FIS Global Hiring Entry-Level Java Support with C,SQL,RDBMS', 'listing_url': 'https://jobsnet.in/fis-global-hiring-entry-level-java-support-with-csqlrdbms/', 'posted_date': datetime.date(2026, 1, 22)}
# {'title': 'Nielsen Recruitment Drive 2026 – Hiring Member Of Technical Staff 1', 'listing_url': 'https://jobsnet.in/nielsen-recruitment-drive-2026-hiring-member-of-technical-staff-1/', 'posted_date': datetime.date(2026, 1, 21)}
# {'title': 'Swiggy Hiring Associate Software Engineer – Android', 'listing_url': 'https://jobsnet.in/swiggy-hiring-associate-software-engineer-android/', 'posted_date': datetime.date(2026, 1, 21)}
# {'title': 'Yash Technologies Off Campus Drive 2026: Trainee – Data Scientist Freshers', 'listing_url': 'https://jobsnet.in/yash-technologies-off-campus-drive-trainee-data-scientist-freshers/', 'posted_date': datetime.date(2026, 1, 21)}
# {'title': 'Red Hat Off Campus Drive 2026 : Associate Software/Maintenance\xa0Engineer Trainee', 'listing_url': 'https://jobsnet.in/red-hat-off-campus-drive-associate-software-maintenance-engineer-trainee/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'IBM Off Campus Drive 2026 – Hiring Freshers As Associate System Engineer', 'listing_url': 'https://jobsnet.in/ibm-off-campus-drive-hiring-freshers-as-associate-system-engineer/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'Syniverse Off Campus Drive 2026 | Graduate Apprentice Trainee | Hybrid', 'listing_url': 'https://jobsnet.in/syniverse-off-campus-drive-graduate-apprentice-trainee-hybrid/', 'posted_date': datetime.date(2026, 1, 19)}
# {'title': 'Siemens Technology Off Campus Drive 2026 – Hiring Java Developer (0-3 Years)', 'listing_url': 'https://jobsnet.in/siemens-technology-off-campus-drive-hiring-java-developer/', 'posted_date': datetime.date(2026, 1, 19)}
# {'title': 'Caterpillar Hiring Entry-Level Java Developer', 'listing_url': 'https://jobsnet.in/caterpillar-hiring-entry-level-java-developer/', 'posted_date': datetime.date(2026, 1, 19)}
# {'title': 'Shell Graduate Programme\xa02026 | Off Campus Hiring | Any Graduate | PAN India', 'listing_url': 'https://jobsnet.in/shell-graduate-programme-off-campus-hiring-any-graduate-early-careers/', 'posted_date': datetime.date(2026, 1, 18)}
# {'title': 'Finastra Off Campus Drive 2026 -Hiring Associate Software Engineer', 'listing_url': 'https://jobsnet.in/finastra-off-campus-drive-hiring-associate-software-engineer/', 'posted_date': datetime.date(2026, 1, 18)}
# {'title': 'Amazon Off Campus Drive  2026 – University Talent Acquisition Drive Hiring For SDE-1', 'listing_url': 'https://jobsnet.in/amazon-university-talent-acquisition-drive-hiring-for-sde-1/', 'posted_date': datetime.date(2026, 1, 18)}
# {'title': 'Fortrea Off Campus Drive 2026: Hiring Apprentice – IT Project Management', 'listing_url': 'https://jobsnet.in/fortrea-off-campus-drive-hiring-apprentice-it-project-management/', 'posted_date': datetime.date(2026, 1, 18)}
# {'title': 'Hitachi Energy Off Campus Drive 2026 – Hiring Entry-Level Full Stack – Java Developer', 'listing_url': 'https://jobsnet.in/hitachi-energy-off-campus-drive-hiring-entry-level-full-stack-java-developer/', 'posted_date': datetime.date(2026, 1, 17)}
# {'title': 'Rockwell Automation Off Campus Drive 2026 : Engineer in Trainee', 'listing_url': 'https://jobsnet.in/rockwell-automation-off-campus-drive-2026-engineer-in-trainee/', 'posted_date': datetime.date(2026, 1, 17)}
# {'title': 'Abstrabit Off Campus Drive 2026 – Hiring Full Stack Engineer (0-2 Years)', 'listing_url': 'https://jobsnet.in/abstrabit-off-campus-drive-hiring-full-stack-engineer/', 'posted_date': datetime.date(2026, 1, 16)}
# {'title': 'CGI Off Campus Drive 2026 – Hiring Associate Software Engineer – Apprentice', 'listing_url': 'https://jobsnet.in/cgi-off-campus-drive-hiring-associate-software-engineer-apprentice/', 'posted_date': datetime.date(2026, 1, 16)}
# {'title': 'Apple Off Campus Drive 2026 – Hiring New Grads As Software Engineer', 'listing_url': 'https://jobsnet.in/apple-off-campus-drive-hiring-new-grads-as-software-engineer/', 'posted_date': datetime.date(2026, 1, 15)}
# {'title': 'FIS Global Off Campus Drive 2026 – Hiring IT Trainee – Java/SQL Developer', 'listing_url': 'https://jobsnet.in/fis-global-off-campus-drive-hiring-it-trainee-java-sql-developer/', 'posted_date': datetime.date(2026, 1, 15)}
# {'title': 'Intuit Off Campus Drive 2026 – Hiring Software Engineer – Full Stack (0-2 Years)', 'listing_url': 'https://jobsnet.in/intuit-off-campus-drive-hiring-software-engineer-full-stack-0-2-years/', 'posted_date': datetime.date(2026, 1, 14)}
# {'title': 'BrowserStack Off Campus Drive 2026 – Hiring Software Engineer – New Grads', 'listing_url': 'https://jobsnet.in/browserstack-off-campus-drive-hiring-software-engineer-grads/', 'posted_date': datetime.date(2026, 1, 14)}
# {'title': 'Zoho Off Campus Drive 2026 – Hiring Software Developers – Freshers (0-4 Years)', 'listing_url': 'https://jobsnet.in/zoho-off-campus-drive-hiring-software-developers-freshers/', 'posted_date': datetime.date(2026, 1, 14)}
# {'title': 'Genpact Off Campus Drive 2026 – Hiring Associate – Data Science Freshers', 'listing_url': 'https://jobsnet.in/genpact-off-campus-drive-2026-hiring-associate-data-science-freshers/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Monotype Off Campus Drive 2026 – Hiring Software Engineer Trainee', 'listing_url': 'https://jobsnet.in/monotype-off-campus-drive-hiring-software-engineer-trainee/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Data Axle\xa0Off Campus 2026 – Hiring Associate Data Engineer', 'listing_url': 'https://jobsnet.in/data-axle-off-campus-hiring-associate-data-engineer/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'SoftwareOne Off Campus Drive 2026 – Hiring Freshers For Data Ops Associate', 'listing_url': 'https://jobsnet.in/softwareone-off-campus-drive-hiring-freshers-for-data-ops-associate/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Adobe Off Campus Drive 2026 Hiring Entry-Level SDE – DevOps', 'listing_url': 'https://jobsnet.in/adobe-off-campus-drive-hiring-entry-level-sde-devops/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Amdocs Off Campus Drive 2026 – Hiring Entry-Level Software Engineer Java + Python', 'listing_url': 'https://jobsnet.in/amdocs-off-campus-drive-hiring-entry-level-software-engineer/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Urban Company Off Campus Drive 2026 | Freshers – Software Engineer', 'listing_url': 'https://jobsnet.in/urban-company-off-campus-drive-freshers-software-engineer/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Nokia Off Campus Drive 2026 – Hiring Software  Development Engineer 1', 'listing_url': 'https://jobsnet.in/nokia-off-campus-drive-hiring-software-development-engineer-1/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Milliman Off Campus Drive 2026 Hiring Freshers Trainee Software Engineer – Full Stack', 'listing_url': 'https://jobsnet.in/milliman-off-campus-drive-hiring-freshers-trainee-full-stack/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Deloitte NLA Off Campus 2026 – Hiring BSC/BCA/BCOM/BBA Or Allied Grads', 'listing_url': 'https://jobsnet.in/deloitte-nla-off-campus-hiring-ug-bsc-bca-bcom-bba-or-allied-grads/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Cognizant Off Campus – Hiring  Engineering Graduates Pan India', 'listing_url': 'https://jobsnet.in/cognizant-off-campus-hiring-2025-engineering-graduates-pan-india/', 'posted_date': datetime.date(2026, 1, 11)}
# {'title': 'Capgemini Off Campus Drive 2026 | Exceller Program | Software Engineer | Pan India', 'listing_url': 'https://jobsnet.in/capgemini-off-campus-drive-2026-exceller-program-software-engineer/', 'posted_date': datetime.date(2026, 1, 11)}
# {'title': 'Infosys EdgeVerve Off Campus Drive 2026 – Systems Engineer', 'listing_url': 'https://jobsnet.in/infosys-edgeverve-off-campus-drive-systems-engineer/', 'posted_date': datetime.date(2026, 1, 11)}
# {'title': 'Remote – Canonical Off Campus Drive 2026 – Hiring Graduate Software Engineer', 'listing_url': 'https://jobsnet.in/canonical-off-campus-drive-hiring-graduate-software-engineer/', 'posted_date': datetime.date(2026, 1, 10)}
# {'title': 'Calix Off Campus Drive 2026 – Hiring Graduate Trainee – Java/J2EE', 'listing_url': 'https://jobsnet.in/calix-off-campus-drive-hiring-graduate-trainee-java-j2ee/', 'posted_date': datetime.date(2026, 1, 10)}
# {'title': 'Deloitte NLA Off Campus Drive 2026 – Hiring Engineering Grads', 'listing_url': 'https://jobsnet.in/deloitte-nla-off-campus-drive-2026-hiring-engineering-grads/', 'posted_date': datetime.date(2026, 1, 10)}
# {'title': 'Swiggy Off Campus Drive Hiring Freshers – Associate Software Engineer', 'listing_url': 'https://jobsnet.in/swiggy-off-campus-drive-hiring-freshers-associate-software-engineer/', 'posted_date': datetime.date(2026, 1, 10)}
# {'title': 'Clario Off Campus Drive 2026 – Hiring Associate Software  Engineer – Remote', 'listing_url': 'https://jobsnet.in/clario-off-campus-drive-hiring-associate-software-engineer-remote/', 'posted_date': datetime.date(2026, 1, 9)}
# {'title': 'TOPSOE Off Campus Drive 2026 Hiring IT Trainee – Software Developer Freshers', 'listing_url': 'https://jobsnet.in/topsoe-off-campus-drive-hiring-it-trainee-freshers/', 'posted_date': datetime.date(2026, 1, 9)}
# {'title': 'NIKE ITC Hiring Entry-Level Software Engineer 1 – Full Stack', 'listing_url': 'https://jobsnet.in/nike-itc-hiring-entry-level-software-engineer/', 'posted_date': datetime.date(2026, 1, 9)}
# {'title': 'DBS Bank Apprenticeship Program 2026 : Hiring BE/B.Tech Grads', 'listing_url': 'https://jobsnet.in/dbs-bank-apprenticeship-program-hiring-be-b-tech-grads/', 'posted_date': datetime.date(2026, 1, 9)}
# {'title': 'Cargill Off Campus Drive 2026 Hiring Associate Software Engineer (0-2 Years)', 'listing_url': 'https://jobsnet.in/cargill-off-campus-drive-hiring-associate-software-engineer/', 'posted_date': datetime.date(2026, 1, 9)}
# {'title': 'Honeywell Off Campus Drive 2026 – Hiring Entry-Level Software Engineers', 'listing_url': 'https://jobsnet.in/honeywell-off-campus-drive-hiring-entry-level-software-engineers/', 'posted_date': datetime.date(2026, 1, 8)}
# {'title': 'Cisco Off Campus Drive 2026 | Technical Graduate Apprentice | Across India', 'listing_url': 'https://jobsnet.in/cisco-off-campus-drive-technical-graduate-apprentice-across-india/', 'posted_date': datetime.date(2026, 1, 8)}
# {'title': 'Zebra Technologies Off Campus Drive 2026 | Software Engineer | 0-2 years', 'listing_url': 'https://jobsnet.in/zebra-technologies-off-campus-drive-software-engineer-0-2-years/', 'posted_date': datetime.date(2026, 1, 7)}
# {'title': 'Konecranes Off Campus Drive 2026 Hiring Graduate Engineer Trainee in Pune', 'listing_url': 'https://jobsnet.in/konecranes-off-campus-drive-hiring-graduate-engineer-trainee-in-pune/', 'posted_date': datetime.date(2026, 1, 6)}
# {'title': 'S&P Global Off Campus Drive 2026 | Associate Software Engineer | Graduate Program', 'listing_url': 'https://jobsnet.in/sp-global-off-campus-drive-2026-associate-software-engineer-graduate-program/', 'posted_date': datetime.date(2026, 1, 6)}
# {'title': 'IBM Hiring Freshers As Associate System Engineer – Pan India', 'listing_url': 'https://jobsnet.in/ibm-hiring-freshers-as-associate-system-engineer-pan-india/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'Dassault Systèmes Off Campus Drive 2026 – Apprentice AI/ML', 'listing_url': 'https://jobsnet.in/dassault-systemes-off-campus-drive-apprentice-ai-ml/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'Equifax Off Campus Drive 2026 – Hiring Entry-Level Automation Engineer', 'listing_url': 'https://jobsnet.in/equifax-off-campus-driv-hiring-entry-level-automation-engineer/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'Cummins Off Campus Drive 2026 | Data Analytics Engineer | Freshers/Early Careers | Pune/Remote', 'listing_url': 'https://jobsnet.in/cummins-off-campus-drive-hiring-data-analytics-engineer/', 'posted_date': datetime.date(2026, 1, 4)}
# {'title': 'Rockwell Automation Hiring Entry-Level Associate software Engineer – Java', 'listing_url': 'https://jobsnet.in/rockwell-automation-hiring-entry-level-associate-software-engineer-java/', 'posted_date': datetime.date(2026, 1, 4)}
# {'title': 'Honeywell  Hiring Entry-Level Software Engineers – .NET (0-2 Years)', 'listing_url': 'https://jobsnet.in/honeywell-hiring-entry-level-software-engineers-net-0-2-years/', 'posted_date': datetime.date(2026, 1, 3)}
# {'title': 'EY GDS Off Campus Drive 2026 Hiring Freshers As Associate Software Engineer', 'listing_url': 'https://jobsnet.in/ey-gds-off-campus-drive-hiring-freshers-as-associate-software-engineer/', 'posted_date': datetime.date(2026, 1, 3)}
# {'title': 'Qualcomm Off Campus Drive 2026 – Hiring Software Engineer in Test', 'listing_url': 'https://jobsnet.in/qualcomm-off-campus-drive-2026-hiring-software-engineer-in-test/', 'posted_date': datetime.date(2026, 1, 2)}
# {'title': 'SAP Labs Hiring Entry-Level Associate Consultant- SQL/Python (0-3 Years)', 'listing_url': 'https://jobsnet.in/sap-labs-hiring-entry-level-associate-consultant-sql-python/', 'posted_date': datetime.date(2026, 1, 2)}
# {'title': 'Accenture Hiring Application Support Engineer – Any Graduate (0-2 Years)', 'listing_url': 'https://jobsnet.in/accenture-hiring-application-support-engineer-any-graduate-0-2-years/', 'posted_date': datetime.date(2026, 1, 2)}
# {'title': 'Cognizant is Hiring Entry-Level PL/SQL Software Engineer', 'listing_url': 'https://jobsnet.in/cognizant-is-hiring-entry-level-pl-sql-software-engineer/', 'posted_date': datetime.date(2026, 1, 2)}
# {'title': 'SITA Off Campus Drive 2026 Hiring Graduate – Developer', 'listing_url': 'https://jobsnet.in/sita-off-campus-drive-2026-hiring-graduate-developer/', 'posted_date': datetime.date(2026, 1, 1)}
# {'title': 'IQVIA Off Campus Drive 2026 Hiring  Software Development Engineer 1', 'listing_url': 'https://jobsnet.in/iqvia-off-campus-drive-hiring-software-development-engineer-1/', 'posted_date': datetime.date(2026, 1, 1)}
# {'title': 'FIS Global Hiring 2026: Hiring Software Test Analyst', 'listing_url': 'https://jobsnet.in/fis-global-hiring-hiring-software-test-analyst/', 'posted_date': datetime.date(2026, 1, 1)}
# {'title': 'Natwest Technology Off Campus  Drive 2026 : Hiring Software Engineer AIML Freshers', 'listing_url': 'https://jobsnet.in/natwest-technology-off-campus-drive-hiring-software-engineer-aiml-freshers/', 'posted_date': datetime.date(2026, 1, 1)}
# {'title': 'Bajaj Finance Off Campus Drive 2026 Hiring Junior Analyst – Cyber Security', 'listing_url': 'https://jobsnet.in/bajaj-finance-off-campus-drive-hiring-junior-analyst-cyber-security/', 'posted_date': datetime.date(2025, 12, 31)}
# {'title': 'NNE Off Campus Drive 2026 – Hiring Trainee Engineer', 'listing_url': 'https://jobsnet.in/nne-off-campus-drive-hiring-trainee-engineer/', 'posted_date': datetime.date(2025, 12, 31)}
# {'title': 'Citi Group Off Campus Drive 2026 – Hiring GenAI Developer (0-2 Years)', 'listing_url': 'https://jobsnet.in/citi-group-off-campus-drive-hiring-genai-developer/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'CGI Off Campus Drive 2026 | AI/ML Apprentice | Freshers | Chennai', 'listing_url': 'https://jobsnet.in/cgi-off-campus-drive-ai-ml-apprentice-freshers-chennai/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'Konecranes Off Campus Drive 2026 – Hiring Software Engineer Trainee', 'listing_url': 'https://jobsnet.in/konecranes-off-campus-drive-2026-hiring-software-engineer-trainee/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'TCS Ignite & Smart Off Campus Drive 2026 Hiring Freshers Across India', 'listing_url': 'https://jobsnet.in/tcs-off-campus-smart-hiring-drive/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'Teradata Off Campus Drive 2026 Hiring Entry-Level Software Engineer', 'listing_url': 'https://jobsnet.in/teradata-off-campus-drive-hiring-entry-level-software-engineer/', 'posted_date': datetime.date(2025, 12, 29)}
# {'title': 'UST Global Hiring Entry-Level Data Science AI Engineer (0-2 Years)', 'listing_url': 'https://jobsnet.in/ust-global-hiring-entry-level-data-science-ai-engineer-0-2-years/', 'posted_date': datetime.date(2025, 12, 28)}
# {'title': 'PayU Hiring Entry-Level Associate Software Engineer', 'listing_url': 'https://jobsnet.in/payu-hiring-entry-level-associate-software-engineer/', 'posted_date': datetime.date(2025, 12, 28)}
# {'title': 'Invesco Off Campus Drive 2025 : Hiring Graduate Engineer Trainee – Technology', 'listing_url': 'https://jobsnet.in/invesco-off-campus-drive-hiring-graduate-engineer-trainee-technology/', 'posted_date': datetime.date(2025, 12, 27)}

# %%
import requests
from bs4 import BeautifulSoup
import time
job_details = []
for job in jobs:
    job_info = job.copy()
    try:
        response = requests.get(job_info["listing_url"])
        job_page = BeautifulSoup(response.content, "html.parser")
        apply_urls = set()
        for a in job_page.find_all("a", href=True):
            anchor_text = a.get_text(strip=True).lower()
            if any(word in anchor_text for word in ("apply here", "click here", "apply now")):
                apply_urls.add(a["href"])
        if apply_urls:
            job_info["apply_urls"] = list(apply_urls)
        for p in job_page.find_all("p"):
            text_lower = p.get_text(strip=True).lower()
            if "location" in text_lower and ":" in p.text:
                job_info["location"] = p.text.split(":", 1)[-1].strip()
            elif "experience" in text_lower and ":" in p.text:
                job_info["experience"] = p.text.split(":", 1)[-1].strip()
        descriptions = []
        for ul in job_page.find_all("ul", class_="wp-block-list"):
            for li in ul.find_all("li"):
                txt = li.get_text(strip=True)
                if txt:
                    descriptions.append(txt)
        for p in job_page.find_all("p"):
            txt = p.get_text(strip=True)
            if txt.startswith(("•", "-", "–", "*")):
                descriptions.append(txt.lstrip("•-–* ").strip())
        if descriptions:
            job_info["description"] = " ".join(dict.fromkeys(descriptions))
        job_details.append(job_info)
    except Exception as e:
        print(f"Error: {job_info['listing_url']} → {e}")

# %%
cleaned_jobs = None
BLOCKED_KEYWORDS = {'telegram','jobsnet','acciojob', 'whatsapp'}
for job in job_details:
    urls = job.get('apply_urls', [])
    cleaned_urls = {url for url in urls if not any(block in url.lower() for block in BLOCKED_KEYWORDS)}
    job['apply_urls'] = list(cleaned_urls)
normalized_jobs = []
for job in job_details:
    urls = job.get('apply_urls', [])
    if urls:
        for url in urls:
            new_job = job.copy()
            new_job['apply_url'] = url
            new_job.pop('apply_urls', None)
            normalized_jobs.append(new_job)
    else:
        new_job = job.copy()
        new_job['apply_url'] = None
        new_job.pop('apply_urls', None)
        normalized_jobs.append(new_job)
cleaned_jobs = normalized_jobs

# %%
df = pd.DataFrame(cleaned_jobs)
df.location = df.location.fillna('Across India')
df.experience = df.experience.fillna('Freshers')
df.description = df.description.fillna('No detailed description available. Please visit the apply link for more information.')
df['apply_url'] = df['apply_url'].fillna(df['listing_url'])
df.head()

# %%
from sqlalchemy import create_engine
import pandas as pd

DB_URL = "postgresql+psycopg2://postgres:Sunny$123@localhost:35432/pgvector"
engine = create_engine(DB_URL)

# %%
df.to_sql(
    name="jobs",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=500
)
