# %%
from bs4 import BeautifulSoup
import requests
from datetime import *
import pandas as pd
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 Edg/87.0.664.75'}

# %%
jobs = []
today = datetime.today().date()
cutoff_date = today - timedelta(days=30)
page_num = 1
stop_pagination = False
while not stop_pagination:
    page_url = f"https://freshersrecruitment.co.in/category/jobs/page/{page_num}/"
    print(f"Fetching: {page_url}") # Checking
    response = requests.get(page_url, headers=head, timeout=10)
    soup = BeautifulSoup(response.content, "html.parser")
    articles = soup.find_all("article")
    if not articles:
        break  
    for article in articles:
        job = {}
        title_tag = article.find("h2", class_="entry-title")
        if title_tag:
            a_tag = title_tag.find("a", href=True)
            if a_tag:
                job["title"] = a_tag.text.strip()
                job["listing_url"] = a_tag["href"]
        time_tag = article.find("time")
        if time_tag:
            job_date = datetime.strptime(time_tag.text.strip(), "%B %d, %Y").date()
            job["posted_date"] = job_date
            if job_date < cutoff_date:
                stop_pagination = True
                break
        if job.get("listing_url"):
            jobs.append(job)
    if stop_pagination:
        break
    page_num += 1
for job in jobs:
    print(job)
# Out:
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/1/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/2/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/3/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/4/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/5/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/6/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/7/
# Fetching: https://freshersrecruitment.co.in/category/jobs/page/8/
# {'title': 'Sutherland Walk-in Drive 2026 | Hiring for Freshers with Salary Rs 3 LPA', 'listing_url': 'https://freshersrecruitment.co.in/sutherland-walk-in-drive-2026/', 'posted_date': datetime.date(2026, 1, 26)}
# {'title': 'Tech Mahindra Walk-in Interview 2026 | Hiring for Freshers | Salary Rs 4.75 LPA', 'listing_url': 'https://freshersrecruitment.co.in/tech-mahindra-walk-in-interview-2026/', 'posted_date': datetime.date(2026, 1, 26)}
# {'title': 'Wipro Off Campus Hiring 2026 | Recruitment for Freshers | School of IT Infrastructure Management', 'listing_url': 'https://freshersrecruitment.co.in/wipro-off-campus-hiring-2026/', 'posted_date': datetime.date(2026, 1, 25)}
# {'title': 'American Express Off Campus Drive 2026 | Mass Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/american-express-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 25)}
# {'title': 'L&T Off Campus Drive 2026 | Hiring M.Tech Freshers | Salary Rs 6.33 LPA', 'listing_url': 'https://freshersrecruitment.co.in/lt-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 24)}
# {'title': 'GE Healthcare Off Campus Drive 2026 | Hiring for Freshers | Graduate Engineer Trainee', 'listing_url': 'https://freshersrecruitment.co.in/ge-healthcare-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 24)}
# {'title': 'Capgemini Hiring 2026 | Mass Recruitment for Freshers | Salary Rs 4.25 LPA', 'listing_url': 'https://freshersrecruitment.co.in/capgemini-hiring-2026/', 'posted_date': datetime.date(2026, 1, 24)}
# {'title': 'Oracle Recruitment 2026 | Associate Consultant Opportunity in Bangalore', 'listing_url': 'https://freshersrecruitment.co.in/oracle-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 24)}
# {'title': 'Qualcomm Recruitment 2026 | Hiring Freshers Role Of Associate Engineer', 'listing_url': 'https://freshersrecruitment.co.in/qualcomm-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 24)}
# {'title': 'Siemens Off Campus Drive 2026 | A Great Opportunity Role of Senior Executive for Freshers', 'listing_url': 'https://freshersrecruitment.co.in/siemens-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Micron Technology Recruitment 2026 | Hiring for Freshers | Associate Engineer', 'listing_url': 'https://freshersrecruitment.co.in/micron-technology-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Infosys Recruitment for 2026 Batch | Hiring for Freshers | Salary Rs 21 LPA', 'listing_url': 'https://freshersrecruitment.co.in/infosys-recruitment-for-2026-batch-2/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Deloitte Off Campus Jobs 2026 | Hiring Analyst (PL/SQL) | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/deloitte-off-campus-jobs-2026/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Tata Motors Off Campus Drive 2026 | Senior Manager | Salary Rs 10 LPA', 'listing_url': 'https://freshersrecruitment.co.in/tata-motors-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 23)}
# {'title': 'Microsoft Off Campus Drive 2026 | Software Engineer | Freshers / Experienced', 'listing_url': 'https://freshersrecruitment.co.in/microsoft-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 22)}
# {'title': 'IDFC FIRST Bank Recruitment 2026 | Hiring Freshers Role of Developer', 'listing_url': 'https://freshersrecruitment.co.in/idfc-first-bank-recruitment-2026-2/', 'posted_date': datetime.date(2026, 1, 22)}
# {'title': 'Hitachi Recruitment 2026 | Executive Diploma Trainee | Hiring for Freshers', 'listing_url': 'https://freshersrecruitment.co.in/hitachi-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 22)}
# {'title': 'Caterpillar Off Campus Drive 2026 | Mass Hiring Freshers/Experienced | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/caterpillar-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 21)}
# {'title': 'NTT DATA Recruitment 2026 | Hiring for Freshers | Systems Integration Specialist', 'listing_url': 'https://freshersrecruitment.co.in/ntt-data-recruitment-2026-2/', 'posted_date': datetime.date(2026, 1, 21)}
# {'title': 'GE Healthcare Recruitment 2026 | Freshers Jobs | Graduate Engineer Trainee', 'listing_url': 'https://freshersrecruitment.co.in/ge-healthcare-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'Citigroup Off Campus Drive 2026 | Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/citigroup-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'Barclays Off Campus Jobs 2026 | Hiring Freshers | Role Of Assistant Vice President Operations', 'listing_url': 'https://freshersrecruitment.co.in/barclays-off-campus-jobs-2026/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'Maruti Suzuki Recruitment 2026 | Mass Hiing for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/maruti-suzuki-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'Deloitte Hiring for 2026 Batch | Recruitment for Freshers | Salary Rs 4 LPA', 'listing_url': 'https://freshersrecruitment.co.in/deloitte-hiring-for-2026-batch/', 'posted_date': datetime.date(2026, 1, 20)}
# {'title': 'Amazon Off Campus Drive 2026 | Mass Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/amazon-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 19)}
# {'title': 'Capgemini Recruitment 2026 | Hiring for Freshers | Associate Software Engineer', 'listing_url': 'https://freshersrecruitment.co.in/capgemini-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 19)}
# {'title': 'Apple Recruitment 2026 | Mass Hiring Role of Junior Software Developer', 'listing_url': 'https://freshersrecruitment.co.in/apple-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 17)}
# {'title': 'Infosys Internship 2026 | A Great Opportunity to Kick Start Your Career', 'listing_url': 'https://freshersrecruitment.co.in/infosys-internship-2026/', 'posted_date': datetime.date(2026, 1, 17)}
# {'title': 'Virtusa Off Campus Drive 2026 | Recruitment for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/virtusa-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 16)}
# {'title': 'Synopsys Off Campus Drive 2026 | Hiring for Freshers | ASIC & Firmware Design Apprenticeship', 'listing_url': 'https://freshersrecruitment.co.in/synopsys-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 16)}
# {'title': 'Cognizant GenC Recruitment 2026 | Mass Hiring for Freshers | Analyst Trainee', 'listing_url': 'https://freshersrecruitment.co.in/cognizant-genc-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 16)}
# {'title': 'GlobalLogic Off Campus Drive 2026 | Hiring Freshers | Associate Analyst Opportunity', 'listing_url': 'https://freshersrecruitment.co.in/globallogic-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 14)}
# {'title': 'TCS MBA Hiring for 2026 Batch | Recruitment for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/tcs-mba-hiring-for-2026-batch/', 'posted_date': datetime.date(2026, 1, 14)}
# {'title': 'ZOHO Corp Recruitment for 2026 Batch | Mass Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/zoho-corp-recruitment-for-2026-batch/', 'posted_date': datetime.date(2026, 1, 14)}
# {'title': 'Accenture Careers Jobs 2026 | Hiring Freshers Role of Technology Platform Engineer', 'listing_url': 'https://freshersrecruitment.co.in/accenture-careers-jobs-2026/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'IBM Recruitment for 2026 Batch | Hiring Associate System Engineer', 'listing_url': 'https://freshersrecruitment.co.in/ibm-recruitment-for-2026-batch/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Infosys EdgeVerve Systems Recruitment 2026 | Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/infosys-edgeverve-systems-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 13)}
# {'title': 'Cisco Recruitment 2026 | Hiring Freshers for 2025 Batch | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/cisco-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Maruti Suzuki Off Campus Drive 2026 | Hiring for Freshers | Junior Engineer Trainee | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/maruti-suzuki-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Deloitte Recruitment for 2026 Batch | National Level Assessment (NLA) | Register Now', 'listing_url': 'https://freshersrecruitment.co.in/deloitte-recruitment-for-2026-batch/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Hexaware Walk-in Drive 2026 | Mass Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/hexaware-walk-in-drive-2026/', 'posted_date': datetime.date(2026, 1, 12)}
# {'title': 'Wipro Work Integrated Learning Program 2026 | Hiring Freshers With Salary Upto Rs. 23,000/Month', 'listing_url': 'https://freshersrecruitment.co.in/wipro-work-integrated-learning-program-2026/', 'posted_date': datetime.date(2026, 1, 11)}
# {'title': 'Genpact Walk-in Drive 2026 | Hiring for Freshers | Transactions (Backend) roles', 'listing_url': 'https://freshersrecruitment.co.in/genpact-walk-in-drive-2026/', 'posted_date': datetime.date(2026, 1, 11)}
# {'title': 'S&P Global Software Engineer 2026 | Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/sp-global-software-engineer-2026/', 'posted_date': datetime.date(2026, 1, 8)}
# {'title': 'Capgemini Exceller Hiring 2026 | 2025 & 2026 Batch for Freshers | Salary Rs 7.5 LPA Package', 'listing_url': 'https://freshersrecruitment.co.in/capgemini-exceller-hiring-2026/', 'posted_date': datetime.date(2026, 1, 8)}
# {'title': 'Cognizant Walk-in Drive 2026 | Analyst Trainee Opportunity for Freshers Candidates', 'listing_url': 'https://freshersrecruitment.co.in/cognizant-walk-in-drive-2026/', 'posted_date': datetime.date(2026, 1, 8)}
# {'title': 'TCS NQT (National Qualifier Test) 2026 | Hiring Freshers of 2021 to 2027 Batch | Register Now', 'listing_url': 'https://freshersrecruitment.co.in/tcs-nqt-national-qualifier-test-2026/', 'posted_date': datetime.date(2026, 1, 8)}
# {'title': 'Dell Technologies Recruitment 2026 | Hiring for Freshers | Software Engineer | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/dell-technologies-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 7)}
# {'title': 'Qualcomm Off Campus Drive 2026 | Hiring Freshers of 2024 & 2025 Batch | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/qualcomm-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 7)}
# {'title': 'JPMorgan Chase Recruitment 2026 : Mass Hiring for Freshers | Senior Manager of Software Engineering', 'listing_url': 'https://freshersrecruitment.co.in/jpmorgan-chase-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 7)}
# {'title': 'Adobe Off Campus Drive 2026 | Hiring for Freshers | Associate Technical Consultant', 'listing_url': 'https://freshersrecruitment.co.in/adobe-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 7)}
# {'title': 'HPE Recruitment 2026 | Mass Hiring for Freshers | Role of Software Engineer', 'listing_url': 'https://freshersrecruitment.co.in/hpe-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 6)}
# {'title': 'Salesforce Off Campus Drive 2026 | Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/salesforce-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 6)}
# {'title': 'Yash Technologies Recruitment 2026 | Mass Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/yash-technologies-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'IBM Off Campus Drive 2026 | Hiring Freshers for Associate System Engineer Role', 'listing_url': 'https://freshersrecruitment.co.in/ibm-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'Deloitte Recruitment 2026 | Hiring Freshers Role of UX Design Analyst', 'listing_url': 'https://freshersrecruitment.co.in/deloitte-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'Tech Mahindra Off Campus Drive 2026 | Apply for SQL Developer Role for Freshers', 'listing_url': 'https://freshersrecruitment.co.in/tech-mahindra-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 5)}
# {'title': 'IDFC FIRST Bank Recruitment 2026 | SDET Opportunity Jobs for Freshers', 'listing_url': 'https://freshersrecruitment.co.in/idfc-first-bank-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 4)}
# {'title': 'ZOHO Corp Off Campus Drive 2026 | A Great Opportunity for Software Developer', 'listing_url': 'https://freshersrecruitment.co.in/zoho-corp-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 4)}
# {'title': 'Accenture Hiring 2026 | Mass Recruitment Freshers | Associate Software Engineer', 'listing_url': 'https://freshersrecruitment.co.in/accenture-hiring-2026/', 'posted_date': datetime.date(2026, 1, 4)}
# {'title': 'Honeywell Recruitment 2026 | Hiring for Freshers | Software Engineer | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/honeywell-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 3)}
# {'title': 'Ericsson Off Campus Drive 2026 | Network Engineer Hiring for Freshers | Register Now', 'listing_url': 'https://freshersrecruitment.co.in/ericsson-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 3)}
# {'title': 'Amazon Recruitment 2026 | Hiring Freshers as Device Associate Role', 'listing_url': 'https://freshersrecruitment.co.in/amazon-recruitment-2026/', 'posted_date': datetime.date(2026, 1, 2)}
# {'title': 'Cognizant GenC Off Campus Drive 2026 | Mass Hiring Freshers  of 2024 & 2025 Batch | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/cognizant-genc-off-campus-drive-2026/', 'posted_date': datetime.date(2026, 1, 2)}
# {'title': 'Google Recruitment 2026 | Hiring Freshers for 2025 & 2026 Batch | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/google-recruitment-2026/', 'posted_date': datetime.date(2025, 12, 31)}
# {'title': 'Mphasis Off Campus Drive 2026 | Hiring for Freshers | Tr Transaction Procng Off | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/mphasis-off-campus-drive-2026/', 'posted_date': datetime.date(2025, 12, 31)}
# {'title': 'Amazon Work From Home Jobs 2026 | A Great Opportunity for Freshers', 'listing_url': 'https://freshersrecruitment.co.in/amazon-work-from-home-jobs-2026/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'Wipro Off Campus Drive 2026 | Hiring Role for Application Developer | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/wipro-off-campus-drive-2026/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'NTT DATA Recruitment 2026 | Hiring for Freshers | Associate DevOps Engineer | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/ntt-data-recruitment-2026/', 'posted_date': datetime.date(2025, 12, 30)}
# {'title': 'TCS Atlas Hiring 2026 | A Great Opportunity for Freshers 2026 Batch | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/tcs-atlas-hiring-2026/', 'posted_date': datetime.date(2025, 12, 29)}
# {'title': 'Accenture Recruitment 2026 | Hiring for Freshers | Apply for Procure to Pay Operations New Associate', 'listing_url': 'https://freshersrecruitment.co.in/accenture-recruitment-2026/', 'posted_date': datetime.date(2025, 12, 29)}
# {'title': 'Citi Off Campus Drive 2026 | A Great opportunity for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/citi-off-campus-drive-2026/', 'posted_date': datetime.date(2025, 12, 28)}
# {'title': 'Accenture Walk-in Drive 2026 | Hiring for Freshers | Commercial Property Roles', 'listing_url': 'https://freshersrecruitment.co.in/accenture-walk-in-drive-2026/', 'posted_date': datetime.date(2025, 12, 27)}
# {'title': 'S&P Global Off Campus Drive 2026 | Hiring for Freshers | Apply Now', 'listing_url': 'https://freshersrecruitment.co.in/sp-global-off-campus-drive-2026/', 'posted_date': datetime.date(2025, 12, 27)}

# %%
import requests
from bs4 import BeautifulSoup
job_details = []
for job in jobs:
    job_info = job.copy()
    try:
        response = requests.get(job_info["listing_url"])
        response.raise_for_status()
        job_page = BeautifulSoup(response.content, "html.parser")
        apply_urls = set()
        for a in job_page.find_all("a", href=True):
            anchor_text = a.get_text(strip=True).lower()
            if any(word in anchor_text for word in ("apply here", "click here", "apply now")):
                apply_urls.add(a["href"])
        if apply_urls:
            job_info["apply_urls"] = list(apply_urls)
        for ul in job_page.find_all("ul", class_="wp-block-list"):
            for li in ul.find_all("li"):
                strong = li.find("strong")
                if strong:
                    label = strong.get_text(strip=True).lower()
                    value = li.get_text(strip=True).replace(strong.get_text(strip=True), "").lstrip(": ").strip()
                    if "location" in label:
                        job_info["location"] = value
                    elif "experience" in label:
                        job_info["experience"] = value
        descriptions = []
        for ul in job_page.find_all("ul", class_="wp-block-list"):
            for li in ul.find_all("li"):
                txt = li.get_text(strip=True)
                if txt:
                    descriptions.append(txt)
        for p in job_page.find_all("p"):
            txt = p.get_text(strip=True)
            if txt.startswith(("•", "-", "–", "*")):
                descriptions.append(txt.lstrip("•-–* ").strip())
        if descriptions:
            job_info["description"] = " ".join(dict.fromkeys(descriptions))
        job_details.append(job_info)
    except Exception as e:
        print(f"Error: {job_info['listing_url']} → {e}")

# %%
cleaned_jobs = None
BLOCKED_KEYWORDS = {'telegram', 'freshersrecruitment', 'whatsapp'}
for job in job_details:
    urls = job.get('apply_urls', [])
    cleaned_urls = {url for url in urls if not any(block in url.lower() for block in BLOCKED_KEYWORDS)}
    job['apply_urls'] = list(cleaned_urls)
normalized_jobs = []
for job in job_details:
    urls = job.get('apply_urls', [])
    if urls:
        for url in urls:
            new_job = job.copy()
            new_job['apply_url'] = url
            new_job.pop('apply_urls', None)
            normalized_jobs.append(new_job)
    else:
        new_job = job.copy()
        new_job['apply_url'] = None
        new_job.pop('apply_urls', None)
        normalized_jobs.append(new_job)
cleaned_jobs = normalized_jobs

# %%
import pandas as pd
df = pd.DataFrame(cleaned_jobs)
# data.to_csv('jobs1.csv', index=False)

# %%
# df1 = pd.read_csv('jobs.csv')
# df2 = pd.read_csv('jobs1.csv')
# df = pd.concat([df1,df2])
df.location = df.location.fillna('Across India')
df.experience = df.experience.fillna('Freshers')
df.description = df.description.fillna('No detailed description available. Please visit the apply link for more information.')
df['apply_url'] = df['apply_url'].fillna(df['listing_url'])
df.head()
# Out:
#                                                title  \
# 0  Sutherland Walk-in Drive 2026 | Hiring for Fre...
# 1  Tech Mahindra Walk-in Interview 2026 | Hiring ...
# 2  Wipro Off Campus Hiring 2026 | Recruitment for...
# 3  American Express Off Campus Drive 2026 | Mass ...
# 4  L&T Off Campus Drive 2026 | Hiring M.Tech Fres...
#
#                                          listing_url posted_date   experience  \
# 0  https://freshersrecruitment.co.in/sutherland-w...  2026-01-26  0 – 2 Years
# 1  https://freshersrecruitment.co.in/tech-mahindr...  2026-01-26  0 – 3 Years
# 2  https://freshersrecruitment.co.in/wipro-off-ca...  2026-01-25     Freshers
# 3  https://freshersrecruitment.co.in/american-exp...  2026-01-25     Freshers
# 4  https://freshersrecruitment.co.in/lt-off-campu...  2026-01-24     Freshers
#
#        location                                        description  \
# 0       Chennai  Job Role:Technical Voice Support Category:Walk...
# 1         Noida  Job Role:International Voice & Chat Process Qu...
# 2     Pan India  Company Website:www.wipro.com Job Role:School ...
# 3     Bangalore  Job Role:Analyst – Data Science Job Category:I...
# 4  Across India  Company:Larsen & Toubro Job Role:Fresher Job T...
#
#                                            apply_url
# 0  https://www.naukri.com/job-listings-technical-...
# 1  https://www.naukri.com/job-listings-wak-in-dri...
# 2  https://app.joinsuperset.com/join/#/signup/stu...
# 3  https://aexp.eightfold.ai/careers/job/39656450...
# 4  https://app.joinsuperset.com/join/#/signup/stu...

# %%
from sqlalchemy import create_engine
import pandas as pd

DB_URL = "postgresql+psycopg2://postgres:Sunny$123@localhost:35432/pgvector"
engine = create_engine(DB_URL)

# %%
df.to_sql(
    name="jobs",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=500
)
# Out:
# 76
